# %%
# %run test_medical_all.py
# Out:
# [2022-11-26 15:46:50,388][test_medical_all.py][line:308][INFO] start testing!
# [2022-11-26 15:46:50,388][test_medical_all.py][line:308][INFO] start testing!
# SwinTransformerSys expand initial----depths:[2, 2, 2, 2];depths_decoder:[1, 2, 2, 2];drop_path_rate:0.2;num_classes:2
# ---final upsample expand_first---
# Epoch 1/1:   0%|          | 0/1478 [00:00<?, ?it/s<class 'dict'>]
# /openbayes/home/CV_Project/logs/Epoch100-train_loss0.0195-val_Loss0.1340-valStrokeDice_0.9718-valDice_0.9316.pth model loaded.
# Start Validation
# ['/openbayes/input/input3/test_image/Abyssinian_111.png'] : tensor(0.9763)
# /openbayes/input/input3/test_image/Abyssinian_111.png
# hd: 21.95449840010015
# jc: 0.8105705353653772
# sc: 0.9055882994979262
# sp: 0.9738138196713317
# Epoch 1/1:   0%|          | 1/1478 [00:02<1:11:15,  2.89s/it, f_score=0.936]
# ['/openbayes/input/input3/test_image/Abyssinian_113.png'] : tensor(0.9873)
# /openbayes/input/input3/test_image/Abyssinian_113.png
# hd: 60.07495318350236
# ...
